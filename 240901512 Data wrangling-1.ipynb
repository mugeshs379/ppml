# %%
import pandas as pd
d1={"name":["sai","sub","pop"],
"age":[20,21,22]}
d2={
"qualified": [True, True, False]
}
df1=pd.DataFrame(d1)
print("DF1:\n",df1)
df2=pd.DataFrame(d2)
print("DF2:\n",df2)
newdf=df1.join(df2)
print("joining:\n",newdf)
# Out:
# DF1:
#    name  age
# 0  sai   20
# 1  sub   21
# 2  pop   22
# DF2:
#     qualified
# 0       True
# 1       True
# 2      False
# joining:
#    name  age  qualified
# 0  sai   20       True
# 1  sub   21       True
# 2  pop   22      False

# %%
import pandas as pd
dfl = pd.DataFrame([[11,12],[3,4]])
df2 = pd.DataFrame([[5,6],[7,8]])
def myfunc(a,b):
    if(a.sum()>b.sum()):
        return a
    else:
        return b
print(dfl)
print(df2)
print(dfl.combine(df2,myfunc))
# Out:
#     0   1
# 0  11  12
# 1   3   4
#    0  1
# 0  5  6
# 1  7  8
#     0   1
# 0  11  12
# 1   3   4

# %%
import pandas as pd
d1={"name":["sai","sub","pop"],
"age":[20,21,22]}
d1={"name":["sai","sub","pop"],
"age":[15,16,17]}
df1=pd.DataFrame(d1)
print("DF1:\n",df1)
df2 = pd.DataFrame(d2)
print("DF2:\n",df2)
# The merge on 'name' with df2 will likely fail or produce empty results as df2 does not have a 'name' column.
# Assuming d2 was meant to be joined or merged on index, or had a 'name' column previously.
# For demonstration, let's correct the variable names and keep the merge as-is,
# but be aware of the 'name' column issue with df2.
newdf1=df1.merge(df2, left_index=True, right_index=True, how='left')
newdf2=df2.merge(df1, left_index=True, right_index=True, how='right')
print("Left Merge:\n", newdf1)
print("Right Merge:\n",newdf2)
# Out:
# DF1:
#    name  age
# 0  sai   15
# 1  sub   16
# 2  pop   17
# DF2:
#     qualified
# 0       True
# 1       True
# 2      False
# Left Merge:
#    name  age  qualified
# 0  sai   15       True
# 1  sub   16       True
# 2  pop   17      False
# Right Merge:
#     qualified name  age
# 0       True  sai   15
# 1       True  sub   16
# 2      False  pop   17

# %%
#Create Data Frame
df=pd.DataFrame({'team':['A','B','C','D'],
           'points':[90,56,78,88],
           'assists':[12,34,23,44],
            'rebounds':[56,43,55,12]})
#View DataFrame
print(df)
#reshape DataFrame from wide format to long format
df=pd.melt(df,id_vars='team',value_vars=['points','assists','rebounds'])
#View updated DataFrame
print("\nReshaped DataFrame:\n",df)
# Out:
#   team  points  assists  rebounds
# 0    A      90       12        56
# 1    B      56       34        43
# 2    C      78       23        55
# 3    D      88       44        12
#
# Reshaped DataFrame:
#     team  variable  value
# 0     A    points     90
# 1     B    points     56
# 2     C    points     78
# 3     D    points     88
# 4     A   assists     12
# 5     B   assists     34
# 6     C   assists     23
# 7     D   assists     44
# 8     A  rebounds     56
# 9     B  rebounds     43
# 10    C  rebounds     55
# 11    D  rebounds     12
